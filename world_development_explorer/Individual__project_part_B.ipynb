# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanth1242/MKsumanth_data690/blob/main/world_development_explorer/Individual__project_part_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NAME-KEERTHI SUMANTH MEKA
#
# # Factors that influence the economy and growth of a country
#
# ## INDICATORS:
# - Exports of goods and services (% of GDP)
#
# - Trade (% of GDP)
#
# - Industry (including construction), value added (% of GDP)
#
# - GDP per capita, PPP (current international $)
#
# ## Countries compared:
# - India
#
# - United states
#
# - Bangladesh
#
# - Afganisthan
#
# - Sri Lanka
# ## Introduction:
# - Economic growth is defined as a rise or improvement in the market value of an economy's commodities and services through time. This expansion is likewise proportional to the percent rate of rise in real Gross Domestic Product (GDP).

# %%
import pandas as pd
import plotly.express as px

# %%
import plotly

print(plotly.__version__)
# Out:
# 5.7.0

# %%
# !pip install plotly  --upgrade
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.7/dist-packages (5.7.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly) (8.0.1)

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Sumanth1242/MKsumanth_data690/main/world_development_explorer/wdx_long.csv")
df
# Out:
#     Unnamed: 0  Year         value          indicator Country Code  \
# 0            0  2016     37.954296     NE.TRD.GNFS.ZS          BGD
# 1            1  2017     35.304000     NE.TRD.GNFS.ZS          BGD
# 2            2  2018     38.244893     NE.TRD.GNFS.ZS          BGD
# 3            3  2019     36.759300     NE.TRD.GNFS.ZS          BGD
# 4            4  2020     30.519465     NE.TRD.GNFS.ZS          BGD
# ..         ...   ...           ...                ...          ...
# 84          84  2016  58021.400500  NY.GDP.PCAP.PP.CD          USA
# 85          85  2017  60109.655726  NY.GDP.PCAP.PP.CD          USA
# 86          86  2018  63064.418410  NY.GDP.PCAP.PP.CD          USA
# 87          87  2019  65279.529026  NY.GDP.PCAP.PP.CD          USA
# 88          88  2020  63593.443621  NY.GDP.PCAP.PP.CD          USA
#
#      Country Name         Region         Income Group    Lending Type
# 0      Bangladesh     South Asia  Lower middle income             IDA
# 1      Bangladesh     South Asia  Lower middle income             IDA
# 2      Bangladesh     South Asia  Lower middle income             IDA
# 3      Bangladesh     South Asia  Lower middle income             IDA
# 4      Bangladesh     South Asia  Lower middle income             IDA
# ..            ...            ...                  ...             ...
# 84  United States  North America          High income  Not classified
# 85  United States  North America          High income  Not classified
# 86  United States  North America          High income  Not classified
# 87  United States  North America          High income  Not classified
# 88  United States  North America          High income  Not classified
#
# [89 rows x 9 columns]

# %%
df.drop(columns=["Unnamed: 0"],inplace=True)
df
# Out:
#     Year         value          indicator Country Code   Country Name  \
# 0   2016     37.954296     NE.TRD.GNFS.ZS          BGD     Bangladesh
# 1   2017     35.304000     NE.TRD.GNFS.ZS          BGD     Bangladesh
# 2   2018     38.244893     NE.TRD.GNFS.ZS          BGD     Bangladesh
# 3   2019     36.759300     NE.TRD.GNFS.ZS          BGD     Bangladesh
# 4   2020     30.519465     NE.TRD.GNFS.ZS          BGD     Bangladesh
# ..   ...           ...                ...          ...            ...
# 84  2016  58021.400500  NY.GDP.PCAP.PP.CD          USA  United States
# 85  2017  60109.655726  NY.GDP.PCAP.PP.CD          USA  United States
# 86  2018  63064.418410  NY.GDP.PCAP.PP.CD          USA  United States
# 87  2019  65279.529026  NY.GDP.PCAP.PP.CD          USA  United States
# 88  2020  63593.443621  NY.GDP.PCAP.PP.CD          USA  United States
#
#            Region         Income Group    Lending Type
# 0      South Asia  Lower middle income             IDA
# 1      South Asia  Lower middle income             IDA
# 2      South Asia  Lower middle income             IDA
# 3      South Asia  Lower middle income             IDA
# 4      South Asia  Lower middle income             IDA
# ..            ...                  ...             ...
# 84  North America          High income  Not classified
# 85  North America          High income  Not classified
# 86  North America          High income  Not classified
# 87  North America          High income  Not classified
# 88  North America          High income  Not classified
#
# [89 rows x 8 columns]

# %%
df_2016 = df.query("Year == 2016")
df_2016.sample(10)
# Out:
#     Year         value          indicator Country Code   Country Name  \
# 0   2016     37.954296     NE.TRD.GNFS.ZS          BGD     Bangladesh
# 55  2016     27.820976     NV.IND.TOTL.ZS          LKA      Sri Lanka
# 20  2016     16.649715     NE.EXP.GNFS.ZS          BGD     Bangladesh
# 84  2016  58021.400500  NY.GDP.PCAP.PP.CD          USA  United States
# 69  2016   3848.957664  NY.GDP.PCAP.PP.CD          BGD     Bangladesh
# 74  2016   5839.864817  NY.GDP.PCAP.PP.CD          IND          India
# 79  2016  12224.215765  NY.GDP.PCAP.PP.CD          LKA      Sri Lanka
# 10  2016     49.636087     NE.TRD.GNFS.ZS          LKA      Sri Lanka
# 60  2016     17.965095     NV.IND.TOTL.ZS          USA  United States
# 45  2016     27.346118     NV.IND.TOTL.ZS          BGD     Bangladesh
#
#            Region         Income Group    Lending Type
# 0      South Asia  Lower middle income             IDA
# 55     South Asia  Lower middle income            IBRD
# 20     South Asia  Lower middle income             IDA
# 84  North America          High income  Not classified
# 69     South Asia  Lower middle income             IDA
# 74     South Asia  Lower middle income            IBRD
# 79     South Asia  Lower middle income            IBRD
# 10     South Asia  Lower middle income            IBRD
# 60  North America          High income  Not classified
# 45     South Asia  Lower middle income             IDA

# %%
df_2016 = df_2016.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df_2016.head()
# Out:
#     Year      value       indicator Country Code   Country Name  \
# 0   2016  37.954296  NE.TRD.GNFS.ZS          BGD     Bangladesh
# 5   2016  40.082486  NE.TRD.GNFS.ZS          IND          India
# 10  2016  49.636087  NE.TRD.GNFS.ZS          LKA      Sri Lanka
# 15  2016  26.516132  NE.TRD.GNFS.ZS          USA  United States
# 20  2016  16.649715  NE.EXP.GNFS.ZS          BGD     Bangladesh
#
#            Region         Income Group    Lending Type
# 0      South Asia  Lower middle income             IDA
# 5      South Asia  Lower middle income            IBRD
# 10     South Asia  Lower middle income            IBRD
# 15  North America          High income  Not classified
# 20     South Asia  Lower middle income             IDA

# %%
df_pivot = df_2016.pivot(index =['Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot.head()
# Out:
# indicator Country Code   Country Name         Region         Income Group  \
# 0                  AFG    Afghanistan     South Asia           Low income
# 1                  BGD     Bangladesh     South Asia  Lower middle income
# 2                  IND          India     South Asia  Lower middle income
# 3                  LKA      Sri Lanka     South Asia  Lower middle income
# 4                  USA  United States  North America          High income
#
# indicator    Lending Type  NE.EXP.GNFS.ZS  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  \
# 0                     IDA             NaN             NaN       10.466808
# 1                     IDA       16.649715       37.954296       27.346118
# 2                    IBRD       19.158235       40.082486       26.619000
# 3                    IBRD       21.173984       49.636087       27.820976
# 4          Not classified       11.907714       26.516132       17.965095
#
# indicator  NY.GDP.PCAP.PP.CD
# 0                1981.118069
# 1                3848.957664
# 2                5839.864817
# 3               12224.215765
# 4               58021.400500

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country Code       5 non-null      object
#  1   Country Name       5 non-null      object
#  2   Region             5 non-null      object
#  3   Income Group       5 non-null      object
#  4   Lending Type       5 non-null      object
#  5   NE.EXP.GNFS.ZS     4 non-null      float64
#  6   NE.TRD.GNFS.ZS     4 non-null      float64
#  7   NV.IND.TOTL.ZS     5 non-null      float64
#  8   NY.GDP.PCAP.PP.CD  5 non-null      float64
# dtypes: float64(4), object(5)
# memory usage: 488.0+ bytes

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="NE.EXP.GNFS.ZS",
    title="TOP 5 Countries by 2016 Exports of goods and services (% of GDP)",
    color='Country Name',
    labels={"NE.EXP.GNFS.ZS":"2016 Exports of goods and services (% of GDP)"}
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="729039e1-8c80-4b92-8588-48014531e6e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("729039e1-8c80-4b92-8588-48014531e6e3")) {                    Plotly.newPlot(                        "729039e1-8c80-4b92-8588-48014531e6e3",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[16.6497149603],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[19.1582349106],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"v","showlegend":true,"textposition":"auto","x":["Sri Lanka"],"xaxis":"x","y":[21.173983792],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Exports of goods and services (% of GDP)=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[11.9077139899],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[ ...

# %% [markdown]
# #  Economic growth due to exports of goods and services:
# - Export sales growth generates revenue and earnings for firms, allowing them to boost capital expenditure. Higher investment boosts a country's production capacity, which in turn boosts its export potential.
#
# - In the year 2016, the percentage of exports of goods and services contributing to GDP by various countries is depicted in the bar graph above.
#
# - Exports of goods and servieces of United Kingdom serves 27.2% to its GDP and stand at the top which serves more percentage to GDP through its exports.
#
# - The United States exports of goods and services contribute 70.8 percent to its GDP, making it the country with the highest proportion of GDP contributed by exports.
#
# - Sri Lanka with 14.9% of the market, followed by India with 7.13%,Bangladesh with 4.7% and Afganisthan with 2.42%.

# %%
df2 = df.query("indicator in['NE.EXP.GNFS.ZS','NE.TRD.GNFS.ZS','NV.IND.TOTL.ZS','NY.GDP.PCAP.PP.CD']")
df2.head()
# Out:
#    Year      value       indicator Country Code Country Name      Region  \
# 0  2016  37.954296  NE.TRD.GNFS.ZS          BGD   Bangladesh  South Asia
# 1  2017  35.304000  NE.TRD.GNFS.ZS          BGD   Bangladesh  South Asia
# 2  2018  38.244893  NE.TRD.GNFS.ZS          BGD   Bangladesh  South Asia
# 3  2019  36.759300  NE.TRD.GNFS.ZS          BGD   Bangladesh  South Asia
# 4  2020  30.519465  NE.TRD.GNFS.ZS          BGD   Bangladesh  South Asia
#
#           Income Group Lending Type
# 0  Lower middle income          IDA
# 1  Lower middle income          IDA
# 2  Lower middle income          IDA
# 3  Lower middle income          IDA
# 4  Lower middle income          IDA

# %%
df_pivot2 = df2.pivot(index =['Year','Country Code','Country Name','Region','Income Group','Lending Type'], columns='indicator', values='value').reset_index()
df_pivot2.head()
# Out:
# indicator  Year Country Code   Country Name         Region  \
# 0          2016          AFG    Afghanistan     South Asia
# 1          2016          BGD     Bangladesh     South Asia
# 2          2016          IND          India     South Asia
# 3          2016          LKA      Sri Lanka     South Asia
# 4          2016          USA  United States  North America
#
# indicator         Income Group    Lending Type  NE.EXP.GNFS.ZS  \
# 0                   Low income             IDA             NaN
# 1          Lower middle income             IDA       16.649715
# 2          Lower middle income            IBRD       19.158235
# 3          Lower middle income            IBRD       21.173984
# 4                  High income  Not classified       11.907714
#
# indicator  NE.TRD.GNFS.ZS  NV.IND.TOTL.ZS  NY.GDP.PCAP.PP.CD
# 0                     NaN       10.466808        1981.118069
# 1               37.954296       27.346118        3848.957664
# 2               40.082486       26.619000        5839.864817
# 3               49.636087       27.820976       12224.215765
# 4               26.516132       17.965095       58021.400500

# %%
fig = px.line(df_pivot2,
    x="Year",
    y="NV.IND.TOTL.ZS",
    title="TOP 5 Countries by 2016 Industry (including construction), value added (% of GDP)",
    color='Country Name',
    labels={"Year":"Year","NV.IND.TOTL.ZS":"Industry (including construction), value added<br>(% of GDP)"},
    hover_name='Country Name',
    
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="ec1b17b4-f0d3-4a55-90ea-1c6679d51502" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec1b17b4-f0d3-4a55-90ea-1c6679d51502")) {                    Plotly.newPlot(                        "ec1b17b4-f0d3-4a55-90ea-1c6679d51502",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=Afghanistan<br>Year=%{x}<br>Industry (including construction), value added<br>(% of GDP)=%{y}<extra></extra>","hovertext":["Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan"],"legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[10.4668076938,10.0518739969,13.3872469598,14.0581123698,14.0316990961],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=Bangladesh<br>Year=%{x}<br>Industry (including construction), value added<br>(% of GDP)=%{y}<extra></extra>","hovertext":["Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh"],"legendgroup":"Bangladesh","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bangladesh","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[27.3461176034,27.750899983,28.5369876541,29.648678815,29.5398908143],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=India<br>Year=%{x}<br>Industry (including construction), value added<br>(% of GDP)=%{y}<extra></extra>","hovertext":["India","India","India","India","India"],"legendgroup":"India","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"India","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[26.61899994,26.5000166467,26.3828986911,24.1775949697,23.5210324466],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=Sri Lanka<br>Year=%{x}<br>Industry (including construction), value added<br>(% of GDP)=%{y}<extra></extra>","hovertext":["Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka","Sri Lanka"],"legendgroup":"Sri Lanka","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sri Lanka","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[27.8209763949,26.7746986263,26.2570347056,27.4036788952,26.2475369426],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=United States<br>Year=%{x}<br>Industry (including construction), value added<br>(% of GDP)=%{y}<extra></extra>","hovertext":["United States","United States","United States","United States","United States"],"legendgroup":"United States","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"United States","orientation":"v","showlegend":true,"x":[2016,2017,2018,2019,2020],"xaxis":"x","y":[17.9650951868,18.2514054669,18.5278233112,18.1563709662,null],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.222222 ...

# %% [markdown]
# # Economic growth due to Industries:
# - Industrial progress has generally resulted in periods of economic expansion. Increased employment opportunities are provided by industrialization, which raises community income and contributes to the country's economic progress.
#
# - From 2016 through 2021, the graph above depicts the percentage of a country's GDP provided by industries.
#
# - The above graph shows us the percentage of the countries GDP which is provided by the industries from 2016-2021.
#
# - Sri Lanka is at the top of the list, with industries accounting for 25.2 percent of its GDP.
#
# - India begins with 27 percent of GDP provided by industries and finishes in third place with 24.2 percent at the end of 2021.
#
# - Bangladesh is the only country whose statistics have improved over time, and due to the pandemic, the percentage has fallen by 1% from 2019 to 2021.

# %%
fig = px.bar(
    df_pivot,
    x="Country Name",
    y="NE.TRD.GNFS.ZS",
    title="TOP 5 Countries by 2016 Trade (% of GDP)",
    color='Country Name',
    labels={"NE.TRD.GNFS.ZS":"2016 Trade (% of GDP)"}
).update_xaxes(categoryorder="total descending")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="6ada1b32-06a9-4de8-885c-3b8b56789998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ada1b32-06a9-4de8-885c-3b8b56789998")) {                    Plotly.newPlot(                        "6ada1b32-06a9-4de8-885c-3b8b56789998",                        [{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Trade (% of GDP)=%{y}<extra></extra>","legendgroup":"Afghanistan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Afghanistan","offsetgroup":"Afghanistan","orientation":"v","showlegend":true,"textposition":"auto","x":["Afghanistan"],"xaxis":"x","y":[null],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Trade (% of GDP)=%{y}<extra></extra>","legendgroup":"Bangladesh","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[37.954296353],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Trade (% of GDP)=%{y}<extra></extra>","legendgroup":"India","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[40.0824857133],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Trade (% of GDP)=%{y}<extra></extra>","legendgroup":"Sri Lanka","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Sri Lanka","offsetgroup":"Sri Lanka","orientation":"v","showlegend":true,"textposition":"auto","x":["Sri Lanka"],"xaxis":"x","y":[49.6360867171],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country Name=%{x}<br>2016 Trade (% of GDP)=%{y}<extra></extra>","legendgroup":"United States","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[26.5161319324],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourc ...

# %% [markdown]
# # Economic growth due to Trades:
#
# - Countries that are open to international commerce expand faster, increase productivity, and provide higher income and more possibilities to their citizens, all of which contribute to the country's economic progress.
#
# - The graph above illustrates that international trade accounts for 56 percent of the United Kingdom's GDP. The United States, on the other hand, only serves 26% of the world through its trading programs.

# %%
fig = px.pie(
    df_pivot,
    values='NY.GDP.PCAP.PP.CD', 
    names='Country Name',
    title='TOP 5 Countries by 2016 GDP per capita, PPP (current international $)',
    hover_name='Country Code',
)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.11.1.min.js"></script>                <div id="bd8cf934-9b64-4582-9ad5-fd587f5ceadd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd8cf934-9b64-4582-9ad5-fd587f5ceadd")) {                    Plotly.newPlot(                        "bd8cf934-9b64-4582-9ad5-fd587f5ceadd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"<b>%{hovertext}</b><br><br>Country Name=%{label}<br>NY.GDP.PCAP.PP.CD=%{value}<extra></extra>","hovertext":["AFG","BGD","IND","LKA","USA"],"labels":["Afghanistan","Bangladesh","India","Sri Lanka","United States"],"legendgroup":"","name":"","showlegend":true,"values":[1981.118068507,3848.9576636919,5839.8648167534,12224.2157651465,58021.4004997125],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}], ...

# %% [markdown]
# # GDP per capita, PPP (current international $):
# - The gross domestic product (GDP) is a metric that measures the economic output of a country. The number of goods and services produced in a country with a higher GDP will be greater.
#
# - The United States has the highest GDP of 68.4%, while Afganisthan has the lowest GDP of 0.29 percent, as shown in the chart above. Despite minimal contributions from exports and trade to the United States, science and technology have contributed to the country's higher GDP than other countries

# %% [markdown]
# #Conclusion:
# We learned how exports of goods and services, industry, and trade contribute to the economic growth of the respective countries from the above information. We also compared the GDP per capita of five other countries.
