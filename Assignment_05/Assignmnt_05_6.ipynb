# %% [markdown]
# <a href="https://colab.research.google.com/github/Sumanth1242/MKsumanth_data690/blob/main/Assignment_05/Assignmnt_05_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bike Sales

# %%
import numpy as np
import pandas as pd

# %%
falsy_values = (0, False, None, '', [], {})

# %%
any(falsy_values)
# Out:
# False

# %%
a = np.array([2, 2, 3, np.nan, np.nan, 4])

# %%
a.sum()
# Out:
# nan

# %%
np.inf
# Out:
# inf

# %%
np.inf / 3
# Out:
# inf

# %%
np.inf / np.inf
# Out:
# nan

# %%
a[~np.isnan(a)]
# Out:
# array([2., 2., 3., 4.])

# %%
a[np.isfinite(a)].sum()
# Out:
# 11.0

# %%
a[np.isfinite(a)].mean()
# Out:
# 2.75

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isnull(None)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %%
pd.notnull(2)
# Out:
# True

# %%
pd.isnull(pd.Series([1, np.nan, 7]))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
df = pd.DataFrame({
    'Column A': [1, np.nan, 30, np.nan],
    'Column B': [2, 8, 31, np.nan],
    'Column C': [np.nan, 9, 32, 100],
    'Column D': [5, 8, 34, 110],
})

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column A  2 non-null      float64
#  1   Column B  3 non-null      float64
#  2   Column C  3 non-null      float64
#  3   Column D  4 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 256.0 bytes

# %%
df.isnull().sum()
# Out:
# Column A    2
# Column B    1
# Column C    1
# Column D    0
# dtype: int64

# %%
df.dropna(how='all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(how='any')
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(thresh=3)
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34

# %%
df.dropna(thresh=3, axis='columns')
# Out:
#    Column B  Column C  Column D
# 0       2.0       NaN         5
# 1       8.0       9.0         8
# 2      31.0      32.0        34
# 3       NaN     100.0       110

# %%
df.dropna(axis=1)
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110
